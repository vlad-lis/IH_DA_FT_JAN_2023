# %% [markdown]
#  ### Sending requests

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google:", google.status_code)

NBA = response = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA:", NBA.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes:", rotten_tomato.status_code)
# Out:
# Google: 200
# NBA: 401
# Rotten Tomatoes: 403

# %% [markdown]
# Check [here](https://www.restapitutorial.com/httpstatuscodes.html) the meaning of each error code.

# %% [markdown]
# ### json response

# %%
# install if needed
import json

response = requests.get("https://jsonplaceholder.typicode.com/todos")
print(response.status_code)
results = response.json()
results[0]["title"]
# Out:
# 200
# 'delectus aut autem'

# %%
import pandas as pd
# json to pandas dataframe
pd.DataFrame(results)
# Out:
#      userId   id                                              title  completed
# 0         1    1                                 delectus aut autem      False
# 1         1    2                 quis ut nam facilis et officia qui      False
# 2         1    3                                fugiat veniam minus      False
# 3         1    4                                   et porro tempora       True
# 4         1    5  laboriosam mollitia et enim quasi adipisci qui...      False
# ..      ...  ...                                                ...        ...
# 195      10  196                consequuntur aut ut fugit similique       True
# 196      10  197                  dignissimos quo nobis earum saepe       True
# 197      10  198                       quis eius est sint explicabo       True
# 198      10  199                       numquam repellendus a magnam       True
# 199      10  200                       ipsam aperiam voluptates qui      False
#
# [200 rows x 4 columns]

# %% [markdown]
# ### GitHub API
#
# Docs here: https://docs.github.com/en/free-pro-team@latest/rest/reference/activity

# %%
response = requests.get('https://api.github.com/events')

# %%
response.json()
# Out:
# [{'id': '25422925117',
#   'type': 'PushEvent',
#   'actor': {'id': 103926885,
#    'login': 'surafelhabteG',
#    'display_login': 'surafelhabteG',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/surafelhabteG',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/103926885?'},
#   'repo': {'id': 544871361,
#    'name': 'surafelhabteG/ecc-backend',
#    'url': 'https://api.github.com/repos/surafelhabteG/ecc-backend'},
#   'payload': {'push_id': 11759372439,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'd009dd0e0b40c648601b998dc68e758f716029aa',
#    'before': 'd5f9c6dc678ef377d2cebe0c68fcea9e19a0b6d7',
#    'commits': [{'sha': 'd009dd0e0b40c648601b998dc68e758f716029aa',
#      'author': {'email': 'surafel@360ground.com', 'name': 'surafel'},
#      'message': 'miner updates',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/surafelhabteG/ecc-backend/commits/d009dd0e0b40c648601b998dc68e758f716029aa'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'},
#  {'id': '25422925132',
#   'type': 'CreateEvent',
#   'actor': {'id': 44438030,
#    'login': 'Kilian-Jugie',
#    'display_login': 'Kilian-Jugie',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kilian-Jugie',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44438030?'},
#   'repo': {'id': 569621128,
#    'name': 'Kilian-Jugie/EasySave',
#    'url': 'https://api.github.com/repos/Kilian-Jugie/EasySave'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'Old school project in C# of a powerfull saving software',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'},
#  {'id': '25422925105',
#   'type': 'MemberEvent',
#   'actor': {'id': 34384804,
#    'login': 'rjial',
#    'display_login': 'rjial',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rjial',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34384804?'},
#   'repo': {'id': 566707651,
#    'name': 'rjial/paradigma',
#    'url': 'https://api.github.com/repos/rjial/paradigma'},
#   'payload': {'member': {'login': 'MajinSkadi',
#     'id': 78838788,
#     'node_id': 'MDQ6VXNlcjc4ODM4Nzg4',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/78838788?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/MajinSkadi',
#     'html_url': 'https://github.com/MajinSkadi',
#     'followers_url': 'https://api.github.com/users/MajinSkadi/followers',
#     'following_url': 'https://api.github.com/users/MajinSkadi/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/MajinSkadi/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/MajinSkadi/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/MajinSkadi/subscriptions',
#     'organizations_url': 'https://api.github.com/users/MajinSkadi/orgs',
#     'repos_url': 'https://api.github.com/users/MajinSkadi/repos',
#     'events_url': 'https://api.github.com/users/MajinSkadi/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/MajinSkadi/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'action': 'added'},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'},
#  {'id': '25422925107',
#   'type': 'CreateEvent',
#   'actor': {'id': 115879307,
#    'login': 'saliq7',
#    'display_login': 'saliq7',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/saliq7',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115879307?'},
#   'repo': {'id': 569621119,
#    'name': 'saliq7/Naive-Bayes-Spam-Ham',
#    'url': 'https://api.github.com/repos/saliq7/Naive-Bayes-Spam-Ham'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'},
#  {'id': '25422925091',
#   'type': 'PushEvent',
#   'actor': {'id': 19200662,
#    'login': 'guilhermespopolin',
#    'display_login': 'guilhermespopolin',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/guilhermespopolin',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19200662?'},
#   'repo': {'id': 410780408,
#    'name': 'HedvigInsurance/racoon',
#    'url': 'https://api.github.com/repos/HedvigInsurance/racoon'},
#   'payload': {'push_id': 11759372397,
#    'size': 4,
#    'distinct_size': 2,
#    'ref': 'refs/heads/GRW-1720/feat/preselect-insurances-url',
#    'head': '0d398843c18899738caf9e97297348f5a30fa7bb',
#    'before': 'd1ca6a5ff6ce0c2a2abd5ed3cb575388d6542946',
#    'commits': [{'sha': 'e3fe55a64836c04f4376eb5a117020c1f7aa891d',
#      'author': {'email': '29139614+renovate[bot]@users.noreply.github.com',
#       'name': 'renovate[bot]'},
#      'message': 'Update dependency jsdom to v20.0.3 (#916)\n\nCo-authored-by: renovate[bot] <29139614+renovate[bot]@users.noreply.github.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/HedvigInsurance/racoon/commits/e3fe55a64836c04f4376eb5a117020c1f7aa891d'},
#     {'sha': 'a06e437f4cc688a58bcfee4c446cd008c2ddb582',
#      'author': {'email': '29139614+renovate[bot]@users.noreply.github.com',
#       'name': 'renovate[bot]'},
#      'message': 'Update dependency marked to v4.2.3 (#917)\n\nCo-authored-by: renovate[bot] <29139614+renovate[bot]@users.noreply.github.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/HedvigInsurance/racoon/commits/a06e437f4cc688a58bcfee4c446cd008c2ddb582'},
#     {'sha': '45941323e06600721e1a15f93c8e3e2b55e827f0',
#      'author': {'email': 'guilherme@hedvig.com', 'name': 'Guilherme Popolin'},
#      'message': 'feat(LandingPage): preselect insurances based on URL',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/HedvigInsurance/racoon/commits/45941323e06600721e1a15f93c8e3e2b55e827f0'},
#     {'sha': '0d398843c18899738caf9e97297348f5a30fa7bb',
#      'author': {'email': 'guilherme@hedvig.com', 'name': 'Guilherme Popolin'},
#      'message': 'feat(LandingPage): display insurances based on type and initial selection state',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/HedvigInsurance/racoon/commits/0d398843c18899738caf9e97297348f5a30fa7bb'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z',
#   'org': {'id': 31246138,
#    'login': 'HedvigInsurance',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/HedvigInsurance',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31246138?'}},
#  {'id': '25422925078',
#   'type': 'PushEvent',
#   'actor': {'id': 67899934,
#    'login': 'bono039',
#    'display_login': 'bono039',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bono039',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67899934?'},
#   'repo': {'id': 567164916,
#    'name': 'bono039/ohTravel',
#    'url': 'https://api.github.com/repos/bono039/ohTravel'},
#   'payload': {'push_id': 11759372365,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ac89269457e0dc112c3adc86ee199d4687a2944c',
#    'before': '2ebe85d9709378ff02bd09fa1408f1bca8096b28',
#    'commits': [{'sha': 'ac89269457e0dc112c3adc86ee199d4687a2944c',
#      'author': {'email': 'bono039@hanyang.ac.kr', 'name': 'bono039'},
#      'message': '입장권 페이지명 변경',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/bono039/ohTravel/commits/ac89269457e0dc112c3adc86ee199d4687a2944c'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'},
#  {'id': '25422925076',
#   'type': 'PushEvent',
#   'actor': {'id': 112076213,
#    'login': 'LarsAskild',
#    'display_login': 'LarsAskild',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LarsAskild',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112076213?'},
#   'repo': {'id': 528877917,
#    'name': 'RoboticsChallenge/Assignment',
#    'url': 'https://api.github.com/repos/RoboticsChallenge/Assignment'},
#   'payload': {'push_id': 11759372386,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '8df5572ef7d6b6f6bfd8b1526de9cb218ab49260',
#    'before': 'e18d346a66f64a437d74c2d9cdbc6e6951f29ce1',
#    'commits': [{'sha': '8df5572ef7d6b6f6bfd8b1526de9cb218ab49260',
#      'author': {'email': '112076213+LarsAskild@users.noreply.github.com',
#       'name': 'LarsAskild'},
#      'message': 'Add files via upload\n\nScript that calculates the required force in each joint to lift an object of 1 kg(9.81 Newton) to its maximum extent in the y-direction.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/RoboticsChallenge/Assignment/commits/8df5572ef7d6b6f6bfd8b1526de9cb218ab49260'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z',
#   'org': {'id': 112097473,
#    'login': 'RoboticsChallenge',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/RoboticsChallenge',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/112097473?'}},
#  {'id': '25422925046',
#   'type': 'PushEvent',
#   'actor': {'id': 83860259,
#    'login': 'newegg88',
#    'display_login': 'newegg88',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/newegg88',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/83860259?'},
#   'repo': {'id': 555754784,
#    'name': 'newegg88/skjl',
#    'url': 'https://api.github.com/repos/newegg88/skjl'},
#   'payload': {'push_id': 11759372394,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '700a04d7ff7fcbc351bf10c6882a964182d3fa7f',
#    'before': '5bc740e8307dce0e2045c05e833150b0f4af7d2b',
#    'commits': [{'sha': '700a04d7ff7fcbc351bf10c6882a964182d3fa7f',
#      'author': {'email': '83860259+newegg88@users.noreply.github.com',
#       'name': 'newegg88'},
#      'message': '*',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/newegg88/skjl/commits/700a04d7ff7fcbc351bf10c6882a964182d3fa7f'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'},
#  {'id': '25422925035',
#   'type': 'CreateEvent',
#   'actor': {'id': 15876321,
#    'login': 'JakaKokosar',
#    'display_login': 'JakaKokosar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/JakaKokosar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15876321?'},
#   'repo': {'id': 124890676,
#    'name': 'JakaKokosar/orange3-bioinformatics',
#    'url': 'https://api.github.com/repos/JakaKokosar/orange3-bioinformatics'},
#   'payload': {'ref': 'owgenialisexpressions',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'},
#  {'id': '25422925043',
#   'type': 'CreateEvent',
#   'actor': {'id': 88604041,
#    'login': 'teamxhieu',
#    'display_login': 'teamxhieu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/teamxhieu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88604041?'},
#   'repo': {'id': 569621127,
#    'name': 'teamxhieu/a-lam-api-1',
#    'url': 'https://api.github.com/repos/teamxhieu/a-lam-api-1'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'Vina8Tui',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'},
#  {'id': '25422925083',
#   'type': 'PushEvent',
#   'actor': {'id': 94271480,
#    'login': 'DaPhysikist',
#    'display_login': 'DaPhysikist',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DaPhysikist',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94271480?'},
#   'repo': {'id': 552545817,
#    'name': 'ssgadient/Power-Ahn',
#    'url': 'https://api.github.com/repos/ssgadient/Power-Ahn'},
#   'payload': {'push_id': 11759372407,
#    'size': 1,
#    'distinct_size': 0,
#    'ref': 'refs/heads/main',
#    'head': '70b1710bcf1270863a4f425ed6bf4c5a5c589d9b',
#    'before': 'b60b1f237d18d4e2bb5ff6f495b91199ab330231',
#    'commits': [{'sha': '70b1710bcf1270863a4f425ed6bf4c5a5c589d9b',
#      'author': {'email': '94271480+DaPhysikist@users.noreply.github.com',
#       'name': 'Pranav Mehta'},
#      'message': 'fixed annoying truncate issue with getting app IDs',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/ssgadient/Power-Ahn/commits/70b1710bcf1270863a4f425ed6bf4c5a5c589d9b'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'},
#  {'id': '25422925098',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 247352763,
#    'name': 'Crisjimenez/PelicularPrimeng',
#    'url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng'},
#   'payload': {'action': 'closed',
#    'number': 27,
#    'pull_request': {'url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/pulls/27',
#     'id': 869084603,
#     'node_id': 'PR_kwDODr5Nu84zzS27',
#     'html_url': 'https://github.com/Crisjimenez/PelicularPrimeng/pull/27',
#     'diff_url': 'https://github.com/Crisjimenez/PelicularPrimeng/pull/27.diff',
#     'patch_url': 'https://github.com/Crisjimenez/PelicularPrimeng/pull/27.patch',
#     'issue_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/issues/27',
#     'number': 27,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump karma from 4.0.1 to 6.3.16',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [karma](https://github.com/karma-runner/karma) from 4.0.1 to 6.3.16.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/karma-runner/karma/releases">karma\'s releases</a>.</em></p>\n<blockquote>\n<h2>v6.3.16</h2>\n<h2><a href="https://github.com/karma-runner/karma/compare/v6.3.15...v6.3.16">6.3.16</a> (2022-02-10)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li><strong>security:</strong> mitigate the &quot;Open Redirect Vulnerability&quot; (<a href="https://github.com/karma-runner/karma/commit/ff7edbb2ffbcdd69761bece86b7dc1ef0740508d">ff7edbb</a>)</li>\n</ul>\n<h2>v6.3.15</h2>\n<h2><a href="https://github.com/karma-runner/karma/compare/v6.3.14...v6.3.15">6.3.15</a> (2022-02-05)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li><strong>helper:</strong> make mkdirIfNotExists helper resilient to concurrent calls (<a href="https://github.com/karma-runner/karma/commit/d9dade2f004a340e49c9a633177576200c286404">d9dade2</a>), closes <a href="https://github-redirect.dependabot.com//github-redirect.dependabot.com/karma-runner/karma-coverage/issues/434/issues/issuecomment-1017939333">karma-runner/karma-coverage#434</a></li>\n</ul>\n<h2>v6.3.14</h2>\n<h2><a href="https://github.com/karma-runner/karma/compare/v6.3.13...v6.3.14">6.3.14</a> (2022-02-05)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>remove string template from client code (<a href="https://github.com/karma-runner/karma/commit/91d5acda6325caf91685da465d688527bd412b47">91d5acd</a>)</li>\n<li>warn when <code>singleRun</code> and <code>autoWatch</code> are <code>false</code> (<a href="https://github.com/karma-runner/karma/commit/69cfc763c8f83e8e7e64d34e17829d0d3dcc0449">69cfc76</a>)</li>\n<li><strong>security:</strong> remove XSS vulnerability in <code>returnUrl</code> query param (<a href="https://github.com/karma-runner/karma/commit/839578c45a8ac42fbc1d72105f97eab77dd3eb8a">839578c</a>)</li>\n</ul>\n<h2>v6.3.13</h2>\n<h2><a href="https://github.com/karma-runner/karma/compare/v6.3.12...v6.3.13">6.3.13</a> (2022-01-31)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li><strong>deps:</strong> bump log4js to resolve security issue (<a href="https://github.com/karma-runner/karma/commit/5bf2df304453c8f71ebc725653fd174ddb1dd28b">5bf2df3</a>), closes <a href="https://github-redirect.dependabot.com/karma-runner/karma/issues/3751">#3751</a></li>\n</ul>\n<h2>v6.3.12</h2>\n<h2><a href="https://github.com/karma-runner/karma/compare/v6.3.11...v6.3.12">6.3.12</a> (2022-01-24)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>remove depreciation warning from log4js (<a href="https://github.com/karma-runner/karma/commit/41bed33bf4b88c7e0787ca3a5ec15f2913b936fd">41bed33</a>)</li>\n</ul>\n<h2>v6.3.11</h2>\n<h2><a href="https://github.com/karma-runner/karma/compare/v6.3.10...v6.3.11">6.3.11</a> (2022-01-13)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li><strong>deps:</strong> pin colors package to 1.4.0 due to security vulnerability (<a href="https://github.com/karma-runner/karma/commit/a5219c52e2515248eefae4fe1863ac8ad3fdd43b">a5219c5</a>)</li>\n</ul>\n<!-- raw HTML omitted -->\n</blockquote>\n<p>... (truncated)</p>\n</details>\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/karma-runner/karma/blob/master/CHANGELOG.md">karma\'s changelog</a>.</em></p>\n<blockquote>\n<h2><a href="https://github.com/karma-runner/karma/compare/v6.3.15...v6.3.16">6.3.16</a> (2022-02-10)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li><strong>security:</strong> mitigate the &quot;Open Redirect Vulnerability&quot; (<a href="https://github.com/karma-runner/karma/commit/ff7edbb2ffbcdd69761bece86b7dc1ef0740508d">ff7edbb</a>)</li>\n</ul>\n<h2><a href="https://github.com/karma-runner/karma/compare/v6.3.14...v6.3.15">6.3.15</a> (2022-02-05)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li><strong>helper:</strong> make mkdirIfNotExists helper resilient to concurrent calls (<a href="https://github.com/karma-runner/karma/commit/d9dade2f004a340e49c9a633177576200c286404">d9dade2</a>), closes <a href="https://github-redirect.de ...
#     'created_at': '2022-03-02T07:45:22Z',
#     'updated_at': '2022-11-23T08:44:20Z',
#     'closed_at': '2022-11-23T08:44:20Z',
#     'merged_at': None,
#     'merge_commit_sha': '0e3c6d9a6cc4f65766afa8c5821d602336f83a9f',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1909725062,
#       'node_id': 'MDU6TGFiZWwxOTA5NzI1MDYy',
#       'url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/pulls/27/commits',
#     'review_comments_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/pulls/27/comments',
#     'review_comment_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/issues/27/comments',
#     'statuses_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/statuses/4256957f4cf7d04612f21742eb4937b272118b70',
#     'head': {'label': 'Crisjimenez:dependabot/npm_and_yarn/karma-6.3.16',
#      'ref': 'dependabot/npm_and_yarn/karma-6.3.16',
#      'sha': '4256957f4cf7d04612f21742eb4937b272118b70',
#      'user': {'login': 'Crisjimenez',
#       'id': 49579936,
#       'node_id': 'MDQ6VXNlcjQ5NTc5OTM2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/49579936?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Crisjimenez',
#       'html_url': 'https://github.com/Crisjimenez',
#       'followers_url': 'https://api.github.com/users/Crisjimenez/followers',
#       'following_url': 'https://api.github.com/users/Crisjimenez/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Crisjimenez/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Crisjimenez/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Crisjimenez/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Crisjimenez/orgs',
#       'repos_url': 'https://api.github.com/users/Crisjimenez/repos',
#       'events_url': 'https://api.github.com/users/Crisjimenez/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Crisjimenez/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 247352763,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDczNTI3NjM=',
#       'name': 'PelicularPrimeng',
#       'full_name': 'Crisjimenez/PelicularPrimeng',
#       'private': False,
#       'owner': {'login': 'Crisjimenez',
#        'id': 49579936,
#        'node_id': 'MDQ6VXNlcjQ5NTc5OTM2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/49579936?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Crisjimenez',
#        'html_url': 'https://github.com/Crisjimenez',
#        'followers_url': 'https://api.github.com/users/Crisjimenez/followers',
#        'following_url': 'https://api.github.com/users/Crisjimenez/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Crisjimenez/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Crisjimenez/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Crisjimenez/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Crisjimenez/orgs',
#        'repos_url': 'https://api.github.com/users/Crisjimenez/repos',
#        'events_url': 'https://api.github.com/users/Crisjimenez/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Crisjimenez/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Crisjimenez/PelicularPrimeng',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng',
#       'forks_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/forks',
#       'keys_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/teams',
#       'hooks_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/events',
#       'assignees_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/tags',
#       'blobs_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/languages',
#       'stargazers_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/subscription',
#       'commits_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/merges',
#       'archive_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/downloads',
#       'issues_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/deployments',
#       'created_at': '2020-03-14T21:02:33Z',
#       'updated_at': '2020-03-14T21:07:51Z',
#       'pushed_at': '2022-11-23T08:44:17Z',
#       'git_url': 'git://github.com/Crisjimenez/PelicularPrimeng.git',
#       'ssh_url': 'git@github.com:Crisjimenez/PelicularPrimeng.git',
#       'clone_url': 'https://github.com/Crisjimenez/PelicularPrimeng.git',
#       'svn_url': 'https://github.com/Crisjimenez/PelicularPrimeng',
#       'homepage': None,
#       'size': 2473,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 21,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 21,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'Crisjimenez:master',
#      'ref': 'master',
#      'sha': 'd998517a89b6006aadf723317c04b4e1fe58f668',
#      'user': {'login': 'Crisjimenez',
#       'id': 49579936,
#       'node_id': 'MDQ6VXNlcjQ5NTc5OTM2',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/49579936?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Crisjimenez',
#       'html_url': 'https://github.com/Crisjimenez',
#       'followers_url': 'https://api.github.com/users/Crisjimenez/followers',
#       'following_url': 'https://api.github.com/users/Crisjimenez/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Crisjimenez/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Crisjimenez/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Crisjimenez/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Crisjimenez/orgs',
#       'repos_url': 'https://api.github.com/users/Crisjimenez/repos',
#       'events_url': 'https://api.github.com/users/Crisjimenez/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Crisjimenez/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 247352763,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDczNTI3NjM=',
#       'name': 'PelicularPrimeng',
#       'full_name': 'Crisjimenez/PelicularPrimeng',
#       'private': False,
#       'owner': {'login': 'Crisjimenez',
#        'id': 49579936,
#        'node_id': 'MDQ6VXNlcjQ5NTc5OTM2',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/49579936?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Crisjimenez',
#        'html_url': 'https://github.com/Crisjimenez',
#        'followers_url': 'https://api.github.com/users/Crisjimenez/followers',
#        'following_url': 'https://api.github.com/users/Crisjimenez/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Crisjimenez/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Crisjimenez/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Crisjimenez/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Crisjimenez/orgs',
#        'repos_url': 'https://api.github.com/users/Crisjimenez/repos',
#        'events_url': 'https://api.github.com/users/Crisjimenez/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Crisjimenez/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Crisjimenez/PelicularPrimeng',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng',
#       'forks_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/forks',
#       'keys_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/teams',
#       'hooks_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/events',
#       'assignees_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/tags',
#       'blobs_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/languages',
#       'stargazers_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/subscription',
#       'commits_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/merges',
#       'archive_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/downloads',
#       'issues_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/deployments',
#       'created_at': '2020-03-14T21:02:33Z',
#       'updated_at': '2020-03-14T21:07:51Z',
#       'pushed_at': '2022-11-23T08:44:17Z',
#       'git_url': 'git://github.com/Crisjimenez/PelicularPrimeng.git',
#       'ssh_url': 'git@github.com:Crisjimenez/PelicularPrimeng.git',
#       'clone_url': 'https://github.com/Crisjimenez/PelicularPrimeng.git',
#       'svn_url': 'https://github.com/Crisjimenez/PelicularPrimeng',
#       'homepage': None,
#       'size': 2473,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 21,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 21,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/pulls/27'},
#      'html': {'href': 'https://github.com/Crisjimenez/PelicularPrimeng/pull/27'},
#      'issue': {'href': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/issues/27'},
#      'comments': {'href': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/issues/27/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/pulls/27/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/pulls/27/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Crisjimenez/PelicularPrimeng/statuses/4256957f4cf7d04612f21742eb4937b272118b70'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 1,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 577,
#     'deletions': 415,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'},
#  {'id': '25422925036',
#   'type': 'CreateEvent',
#   'actor': {'id': 76932147,
#    'login': 'Mintfrog-1209',
#    'display_login': 'Mintfrog-1209',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mintfrog-1209',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76932147?'},
#   'repo': {'id': 569620488,
#    'name': 'Mintfrog-1209/GROUND',
#    'url': 'https://api.github.com/repos/Mintfrog-1209/GROUND'},
#   'payload': {'ref': 'back-feature/user/fix',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'},
#  {'id': '25422925075',
#   'type': 'DeleteEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 247324642,
#    'name': 'ldex/Angular-Academy-187',
#    'url': 'https://api.github.com/repos/ldex/Angular-Academy-187'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/karma-6.3.16',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'},
#  {'id': '25422925038',
#   'type': 'WatchEvent',
#   'actor': {'id': 118886360,
#    'login': 'Dytosmany',
#    'display_login': 'Dytosmany',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Dytosmany',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118886360?'},
#   'repo': {'id': 21800813,
#    'name': 'dwyl/english-words',
#    'url': 'https://api.github.com/repos/dwyl/english-words'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z',
#   'org': {'id': 11708465,
#    'login': 'dwyl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/dwyl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11708465?'}},
#  {'id': '25422925054',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 38692350,
#    'login': 'hifabienne',
#    'display_login': 'hifabienne',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hifabienne',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38692350?'},
#   'repo': {'id': 247714750,
#    'name': 'zitadel/zitadel',
#    'url': 'https://api.github.com/repos/zitadel/zitadel'},
#   'payload': {'action': 'closed',
#    'number': 4741,
#    'pull_request': {'url': 'https://api.github.com/repos/zitadel/zitadel/pulls/4741',
#     'id': 1133026931,
#     'node_id': 'PR_kwDODsPTvs5DiJ5z',
#     'html_url': 'https://github.com/zitadel/zitadel/pull/4741',
#     'diff_url': 'https://github.com/zitadel/zitadel/pull/4741.diff',
#     'patch_url': 'https://github.com/zitadel/zitadel/pull/4741.patch',
#     'issue_url': 'https://api.github.com/repos/zitadel/zitadel/issues/4741',
#     'number': 4741,
#     'state': 'closed',
#     'locked': False,
#     'title': 'docs: scenario login with email',
#     'user': {'login': 'hifabienne',
#      'id': 38692350,
#      'node_id': 'MDQ6VXNlcjM4NjkyMzUw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/38692350?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/hifabienne',
#      'html_url': 'https://github.com/hifabienne',
#      'followers_url': 'https://api.github.com/users/hifabienne/followers',
#      'following_url': 'https://api.github.com/users/hifabienne/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/hifabienne/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/hifabienne/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/hifabienne/subscriptions',
#      'organizations_url': 'https://api.github.com/users/hifabienne/orgs',
#      'repos_url': 'https://api.github.com/users/hifabienne/repos',
#      'events_url': 'https://api.github.com/users/hifabienne/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/hifabienne/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2022-11-23T07:51:54Z',
#     'updated_at': '2022-11-23T08:44:19Z',
#     'closed_at': '2022-11-23T08:44:19Z',
#     'merged_at': '2022-11-23T08:44:19Z',
#     'merge_commit_sha': 'ff595697df411fb02d5b994a3c6a90a16316dce2',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/zitadel/zitadel/pulls/4741/commits',
#     'review_comments_url': 'https://api.github.com/repos/zitadel/zitadel/pulls/4741/comments',
#     'review_comment_url': 'https://api.github.com/repos/zitadel/zitadel/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/zitadel/zitadel/issues/4741/comments',
#     'statuses_url': 'https://api.github.com/repos/zitadel/zitadel/statuses/43cb3d3bb120a254b702bd83099654440cc91b57',
#     'head': {'label': 'zitadel:docs_scenarios',
#      'ref': 'docs_scenarios',
#      'sha': '43cb3d3bb120a254b702bd83099654440cc91b57',
#      'user': {'login': 'zitadel',
#       'id': 70011121,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjcwMDExMTIx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/70011121?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/zitadel',
#       'html_url': 'https://github.com/zitadel',
#       'followers_url': 'https://api.github.com/users/zitadel/followers',
#       'following_url': 'https://api.github.com/users/zitadel/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/zitadel/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/zitadel/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/zitadel/subscriptions',
#       'organizations_url': 'https://api.github.com/users/zitadel/orgs',
#       'repos_url': 'https://api.github.com/users/zitadel/repos',
#       'events_url': 'https://api.github.com/users/zitadel/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/zitadel/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 247714750,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDc3MTQ3NTA=',
#       'name': 'zitadel',
#       'full_name': 'zitadel/zitadel',
#       'private': False,
#       'owner': {'login': 'zitadel',
#        'id': 70011121,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjcwMDExMTIx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/70011121?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/zitadel',
#        'html_url': 'https://github.com/zitadel',
#        'followers_url': 'https://api.github.com/users/zitadel/followers',
#        'following_url': 'https://api.github.com/users/zitadel/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/zitadel/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/zitadel/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/zitadel/subscriptions',
#        'organizations_url': 'https://api.github.com/users/zitadel/orgs',
#        'repos_url': 'https://api.github.com/users/zitadel/repos',
#        'events_url': 'https://api.github.com/users/zitadel/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/zitadel/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/zitadel/zitadel',
#       'description': 'ZITADEL - The best of Auth0 and Keycloak combined. Built for the serverless era.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/zitadel/zitadel',
#       'forks_url': 'https://api.github.com/repos/zitadel/zitadel/forks',
#       'keys_url': 'https://api.github.com/repos/zitadel/zitadel/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/zitadel/zitadel/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/zitadel/zitadel/teams',
#       'hooks_url': 'https://api.github.com/repos/zitadel/zitadel/hooks',
#       'issue_events_url': 'https://api.github.com/repos/zitadel/zitadel/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/zitadel/zitadel/events',
#       'assignees_url': 'https://api.github.com/repos/zitadel/zitadel/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/zitadel/zitadel/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/zitadel/zitadel/tags',
#       'blobs_url': 'https://api.github.com/repos/zitadel/zitadel/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/zitadel/zitadel/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/zitadel/zitadel/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/zitadel/zitadel/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/zitadel/zitadel/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/zitadel/zitadel/languages',
#       'stargazers_url': 'https://api.github.com/repos/zitadel/zitadel/stargazers',
#       'contributors_url': 'https://api.github.com/repos/zitadel/zitadel/contributors',
#       'subscribers_url': 'https://api.github.com/repos/zitadel/zitadel/subscribers',
#       'subscription_url': 'https://api.github.com/repos/zitadel/zitadel/subscription',
#       'commits_url': 'https://api.github.com/repos/zitadel/zitadel/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/zitadel/zitadel/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/zitadel/zitadel/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/zitadel/zitadel/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/zitadel/zitadel/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/zitadel/zitadel/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/zitadel/zitadel/merges',
#       'archive_url': 'https://api.github.com/repos/zitadel/zitadel/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/zitadel/zitadel/downloads',
#       'issues_url': 'https://api.github.com/repos/zitadel/zitadel/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/zitadel/zitadel/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/zitadel/zitadel/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/zitadel/zitadel/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/zitadel/zitadel/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/zitadel/zitadel/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/zitadel/zitadel/deployments',
#       'created_at': '2020-03-16T13:51:31Z',
#       'updated_at': '2022-11-23T08:04:49Z',
#       'pushed_at': '2022-11-23T08:44:19Z',
#       'git_url': 'git://github.com/zitadel/zitadel.git',
#       'ssh_url': 'git@github.com:zitadel/zitadel.git',
#       'clone_url': 'https://github.com/zitadel/zitadel.git',
#       'svn_url': 'https://github.com/zitadel/zitadel',
#       'homepage': 'https://zitadel.com',
#       'size': 328070,
#       'stargazers_count': 1706,
#       'watchers_count': 1706,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': True,
#       'forks_count': 101,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 254,
#       'license': {'key': 'apache-2.0',
#        'name': 'Apache License 2.0',
#        'spdx_id': 'Apache-2.0',
#        'url': 'https://api.github.com/licenses/apache-2.0',
#        'node_id': 'MDc6TGljZW5zZTI='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': ['2fa',
#        'auth',
#        'authentication',
#        'authorization',
#        'cloud-native',
#        'fido2',
#        'jwt',
#        'login',
#        'mfa',
#        'oauth2',
#        'oidc',
#        'openid-connect',
#        'saml',
#        'serverless',
#        'sso'],
#       'visibility': 'public',
#       'forks': 101,
#       'open_issues': 254,
#       'watchers': 1706,
#       'default_branch': 'main'}},
#     'base': {'label': 'zitadel:main',
#      'ref': 'main',
#      'sha': 'e8babf1048e93070b003261a923ea470e9925268',
#      'user': {'login': 'zitadel',
# ...
#        'node_id': 'MDQ6VXNlcjU3MDc2MTEy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/57076112?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/cristobalobos',
#        'html_url': 'https://github.com/cristobalobos',
#        'followers_url': 'https://api.github.com/users/cristobalobos/followers',
#        'following_url': 'https://api.github.com/users/cristobalobos/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/cristobalobos/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/cristobalobos/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/cristobalobos/subscriptions',
#        'organizations_url': 'https://api.github.com/users/cristobalobos/orgs',
#        'repos_url': 'https://api.github.com/users/cristobalobos/repos',
#        'events_url': 'https://api.github.com/users/cristobalobos/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/cristobalobos/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/cristobalobos/angularescencial',
#       'description': 'Curso Angular ',
#       'fork': False,
#       'url': 'https://api.github.com/repos/cristobalobos/angularescencial',
#       'forks_url': 'https://api.github.com/repos/cristobalobos/angularescencial/forks',
#       'keys_url': 'https://api.github.com/repos/cristobalobos/angularescencial/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/cristobalobos/angularescencial/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/cristobalobos/angularescencial/teams',
#       'hooks_url': 'https://api.github.com/repos/cristobalobos/angularescencial/hooks',
#       'issue_events_url': 'https://api.github.com/repos/cristobalobos/angularescencial/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/cristobalobos/angularescencial/events',
#       'assignees_url': 'https://api.github.com/repos/cristobalobos/angularescencial/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/cristobalobos/angularescencial/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/cristobalobos/angularescencial/tags',
#       'blobs_url': 'https://api.github.com/repos/cristobalobos/angularescencial/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/cristobalobos/angularescencial/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/cristobalobos/angularescencial/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/cristobalobos/angularescencial/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/cristobalobos/angularescencial/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/cristobalobos/angularescencial/languages',
#       'stargazers_url': 'https://api.github.com/repos/cristobalobos/angularescencial/stargazers',
#       'contributors_url': 'https://api.github.com/repos/cristobalobos/angularescencial/contributors',
#       'subscribers_url': 'https://api.github.com/repos/cristobalobos/angularescencial/subscribers',
#       'subscription_url': 'https://api.github.com/repos/cristobalobos/angularescencial/subscription',
#       'commits_url': 'https://api.github.com/repos/cristobalobos/angularescencial/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/cristobalobos/angularescencial/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/cristobalobos/angularescencial/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/cristobalobos/angularescencial/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/cristobalobos/angularescencial/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/cristobalobos/angularescencial/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/cristobalobos/angularescencial/merges',
#       'archive_url': 'https://api.github.com/repos/cristobalobos/angularescencial/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/cristobalobos/angularescencial/downloads',
#       'issues_url': 'https://api.github.com/repos/cristobalobos/angularescencial/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/cristobalobos/angularescencial/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/cristobalobos/angularescencial/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/cristobalobos/angularescencial/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/cristobalobos/angularescencial/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/cristobalobos/angularescencial/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/cristobalobos/angularescencial/deployments',
#       'created_at': '2020-03-15T02:26:08Z',
#       'updated_at': '2020-03-15T03:15:05Z',
#       'pushed_at': '2022-11-23T08:44:19Z',
#       'git_url': 'git://github.com/cristobalobos/angularescencial.git',
#       'ssh_url': 'git@github.com:cristobalobos/angularescencial.git',
#       'clone_url': 'https://github.com/cristobalobos/angularescencial.git',
#       'svn_url': 'https://github.com/cristobalobos/angularescencial',
#       'homepage': None,
#       'size': 2896,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 21,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 21,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'cristobalobos:master',
#      'ref': 'master',
#      'sha': '9091322f3f20eccb7bf9ac2aeb6c634be787646b',
#      'user': {'login': 'cristobalobos',
#       'id': 57076112,
#       'node_id': 'MDQ6VXNlcjU3MDc2MTEy',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/57076112?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/cristobalobos',
#       'html_url': 'https://github.com/cristobalobos',
#       'followers_url': 'https://api.github.com/users/cristobalobos/followers',
#       'following_url': 'https://api.github.com/users/cristobalobos/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/cristobalobos/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/cristobalobos/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/cristobalobos/subscriptions',
#       'organizations_url': 'https://api.github.com/users/cristobalobos/orgs',
#       'repos_url': 'https://api.github.com/users/cristobalobos/repos',
#       'events_url': 'https://api.github.com/users/cristobalobos/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/cristobalobos/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 247387618,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNDczODc2MTg=',
#       'name': 'angularescencial',
#       'full_name': 'cristobalobos/angularescencial',
#       'private': False,
#       'owner': {'login': 'cristobalobos',
#        'id': 57076112,
#        'node_id': 'MDQ6VXNlcjU3MDc2MTEy',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/57076112?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/cristobalobos',
#        'html_url': 'https://github.com/cristobalobos',
#        'followers_url': 'https://api.github.com/users/cristobalobos/followers',
#        'following_url': 'https://api.github.com/users/cristobalobos/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/cristobalobos/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/cristobalobos/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/cristobalobos/subscriptions',
#        'organizations_url': 'https://api.github.com/users/cristobalobos/orgs',
#        'repos_url': 'https://api.github.com/users/cristobalobos/repos',
#        'events_url': 'https://api.github.com/users/cristobalobos/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/cristobalobos/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/cristobalobos/angularescencial',
#       'description': 'Curso Angular ',
#       'fork': False,
#       'url': 'https://api.github.com/repos/cristobalobos/angularescencial',
#       'forks_url': 'https://api.github.com/repos/cristobalobos/angularescencial/forks',
#       'keys_url': 'https://api.github.com/repos/cristobalobos/angularescencial/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/cristobalobos/angularescencial/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/cristobalobos/angularescencial/teams',
#       'hooks_url': 'https://api.github.com/repos/cristobalobos/angularescencial/hooks',
#       'issue_events_url': 'https://api.github.com/repos/cristobalobos/angularescencial/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/cristobalobos/angularescencial/events',
#       'assignees_url': 'https://api.github.com/repos/cristobalobos/angularescencial/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/cristobalobos/angularescencial/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/cristobalobos/angularescencial/tags',
#       'blobs_url': 'https://api.github.com/repos/cristobalobos/angularescencial/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/cristobalobos/angularescencial/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/cristobalobos/angularescencial/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/cristobalobos/angularescencial/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/cristobalobos/angularescencial/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/cristobalobos/angularescencial/languages',
#       'stargazers_url': 'https://api.github.com/repos/cristobalobos/angularescencial/stargazers',
#       'contributors_url': 'https://api.github.com/repos/cristobalobos/angularescencial/contributors',
#       'subscribers_url': 'https://api.github.com/repos/cristobalobos/angularescencial/subscribers',
#       'subscription_url': 'https://api.github.com/repos/cristobalobos/angularescencial/subscription',
#       'commits_url': 'https://api.github.com/repos/cristobalobos/angularescencial/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/cristobalobos/angularescencial/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/cristobalobos/angularescencial/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/cristobalobos/angularescencial/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/cristobalobos/angularescencial/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/cristobalobos/angularescencial/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/cristobalobos/angularescencial/merges',
#       'archive_url': 'https://api.github.com/repos/cristobalobos/angularescencial/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/cristobalobos/angularescencial/downloads',
#       'issues_url': 'https://api.github.com/repos/cristobalobos/angularescencial/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/cristobalobos/angularescencial/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/cristobalobos/angularescencial/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/cristobalobos/angularescencial/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/cristobalobos/angularescencial/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/cristobalobos/angularescencial/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/cristobalobos/angularescencial/deployments',
#       'created_at': '2020-03-15T02:26:08Z',
#       'updated_at': '2020-03-15T03:15:05Z',
#       'pushed_at': '2022-11-23T08:44:19Z',
#       'git_url': 'git://github.com/cristobalobos/angularescencial.git',
#       'ssh_url': 'git@github.com:cristobalobos/angularescencial.git',
#       'clone_url': 'https://github.com/cristobalobos/angularescencial.git',
#       'svn_url': 'https://github.com/cristobalobos/angularescencial',
#       'homepage': None,
#       'size': 2896,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 21,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 21,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/cristobalobos/angularescencial/pulls/30'},
#      'html': {'href': 'https://github.com/cristobalobos/angularescencial/pull/30'},
#      'issue': {'href': 'https://api.github.com/repos/cristobalobos/angularescencial/issues/30'},
#      'comments': {'href': 'https://api.github.com/repos/cristobalobos/angularescencial/issues/30/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/cristobalobos/angularescencial/pulls/30/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/cristobalobos/angularescencial/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/cristobalobos/angularescencial/pulls/30/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/cristobalobos/angularescencial/statuses/7d108a2381de16511029ea1c92a9474de349907e'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 415,
#     'deletions': 459,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'},
#  {'id': '25422924901',
#   'type': 'PushEvent',
#   'actor': {'id': 118753327,
#    'login': 'akshayj-chavan',
#    'display_login': 'akshayj-chavan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/akshayj-chavan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/118753327?'},
#   'repo': {'id': 568876709,
#    'name': 'akshayj-chavan/Instagram-Clone',
#    'url': 'https://api.github.com/repos/akshayj-chavan/Instagram-Clone'},
#   'payload': {'push_id': 11759372318,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '82ab28e81e33b8cb3f5d92530b6d53dab7fdc273',
#    'before': '48c5a6d3f752647164b8ab72f2f3c9f0430bd6fe',
#    'commits': [{'sha': '82ab28e81e33b8cb3f5d92530b6d53dab7fdc273',
#      'author': {'email': '118753327+akshayj-chavan@users.noreply.github.com',
#       'name': 'Akshay Chavan'},
#      'message': 'Delete Ass3 -Mahendra Karwa (45) - Jupyter Notebook.pdf',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/akshayj-chavan/Instagram-Clone/commits/82ab28e81e33b8cb3f5d92530b6d53dab7fdc273'}]},
#   'public': True,
#   'created_at': '2022-11-23T08:44:20Z'}]

# %%
pd.DataFrame(response.json())
# Out:
#              id               type  \
# 0   25422925117          PushEvent
# 1   25422925132        CreateEvent
# 2   25422925105        MemberEvent
# 3   25422925107        CreateEvent
# 4   25422925091          PushEvent
# 5   25422925078          PushEvent
# 6   25422925076          PushEvent
# 7   25422925046          PushEvent
# 8   25422925035        CreateEvent
# 9   25422925043        CreateEvent
# 10  25422925083          PushEvent
# 11  25422925098   PullRequestEvent
# 12  25422925036        CreateEvent
# 13  25422925075        DeleteEvent
# 14  25422925038         WatchEvent
# 15  25422925054   PullRequestEvent
# 16  25422925045   PullRequestEvent
# 17  25422924981          PushEvent
# 18  25422924995          PushEvent
# 19  25422924985          PushEvent
# 20  25422924984  IssueCommentEvent
# 21  25422924998          PushEvent
# 22  25422924956        CreateEvent
# 23  25422925023   PullRequestEvent
# 24  25422924999          ForkEvent
# 25  25422924994   PullRequestEvent
# 26  25422924965        CreateEvent
# 27  25422924975        CreateEvent
# 28  25422924969   PullRequestEvent
# 29  25422924901          PushEvent
#
#                                                 actor  \
# 0   {'id': 103926885, 'login': 'surafelhabteG', 'd...
# 1   {'id': 44438030, 'login': 'Kilian-Jugie', 'dis...
# 2   {'id': 34384804, 'login': 'rjial', 'display_lo...
# 3   {'id': 115879307, 'login': 'saliq7', 'display_...
# 4   {'id': 19200662, 'login': 'guilhermespopolin',...
# 5   {'id': 67899934, 'login': 'bono039', 'display_...
# 6   {'id': 112076213, 'login': 'LarsAskild', 'disp...
# 7   {'id': 83860259, 'login': 'newegg88', 'display...
# 8   {'id': 15876321, 'login': 'JakaKokosar', 'disp...
# 9   {'id': 88604041, 'login': 'teamxhieu', 'displa...
# 10  {'id': 94271480, 'login': 'DaPhysikist', 'disp...
# 11  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 12  {'id': 76932147, 'login': 'Mintfrog-1209', 'di...
# 13  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 14  {'id': 118886360, 'login': 'Dytosmany', 'displ...
# 15  {'id': 38692350, 'login': 'hifabienne', 'displ...
# 16  {'id': 49859594, 'login': 'Speedwag00n', 'disp...
# 17  {'id': 106299850, 'login': 'claudiu-muresan-pf...
# 18  {'id': 1201934, 'login': 'a4lg', 'display_logi...
# 19  {'id': 96522200, 'login': 'aishwaryakb', 'disp...
# 20  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 21  {'id': 28045858, 'login': '0lmi', 'display_log...
# 22  {'id': 112081353, 'login': 'AMSAREDD', 'displa...
# 23  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 24  {'id': 13002929, 'login': 'DIT4FUN', 'display_...
# 25  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 26  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 27  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 28  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 29  {'id': 118753327, 'login': 'akshayj-chavan', '...
#
#                                                  repo  \
# 0   {'id': 544871361, 'name': 'surafelhabteG/ecc-b...
# 1   {'id': 569621128, 'name': 'Kilian-Jugie/EasySa...
# 2   {'id': 566707651, 'name': 'rjial/paradigma', '...
# 3   {'id': 569621119, 'name': 'saliq7/Naive-Bayes-...
# 4   {'id': 410780408, 'name': 'HedvigInsurance/rac...
# 5   {'id': 567164916, 'name': 'bono039/ohTravel', ...
# 6   {'id': 528877917, 'name': 'RoboticsChallenge/A...
# 7   {'id': 555754784, 'name': 'newegg88/skjl', 'ur...
# 8   {'id': 124890676, 'name': 'JakaKokosar/orange3...
# 9   {'id': 569621127, 'name': 'teamxhieu/a-lam-api...
# 10  {'id': 552545817, 'name': 'ssgadient/Power-Ahn...
# 11  {'id': 247352763, 'name': 'Crisjimenez/Pelicul...
# 12  {'id': 569620488, 'name': 'Mintfrog-1209/GROUN...
# 13  {'id': 247324642, 'name': 'ldex/Angular-Academ...
# 14  {'id': 21800813, 'name': 'dwyl/english-words',...
# 15  {'id': 247714750, 'name': 'zitadel/zitadel', '...
# 16  {'id': 370271929, 'name': 'luxteam/jobs_test_s...
# 17  {'id': 137921014, 'name': 'waylayio/design-sys...
# 18  {'id': 438178362, 'name': 'a4lg/binutils-gdb',...
# 19  {'id': 569544708, 'name': 'aishwaryakb/ui-test...
# 20  {'id': 247472081, 'name': 'adwd/graphql-codege...
# 21  {'id': 555362223, 'name': 'mendersoftware/mend...
# 22  {'id': 569620960, 'name': 'AMSAREDD/Devrepo', ...
# 23  {'id': 236182372, 'name': 'marceloarb/Coding-D...
# 24  {'id': 13233158, 'name': 'obsproject/obs-studi...
# 25  {'id': 247422451, 'name': 'breaktoprotect/food...
# 26  {'id': 247430054, 'name': 'CocoHuissoon/heroku...
# 27  {'id': 236182372, 'name': 'marceloarb/Coding-D...
# 28  {'id': 247387618, 'name': 'cristobalobos/angul...
# 29  {'id': 568876709, 'name': 'akshayj-chavan/Inst...
#
#                                               payload  public  \
# 0   {'push_id': 11759372439, 'size': 1, 'distinct_...    True
# 1   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 2   {'member': {'login': 'MajinSkadi', 'id': 78838...    True
# 3   {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 4   {'push_id': 11759372397, 'size': 4, 'distinct_...    True
# 5   {'push_id': 11759372365, 'size': 1, 'distinct_...    True
# 6   {'push_id': 11759372386, 'size': 1, 'distinct_...    True
# 7   {'push_id': 11759372394, 'size': 1, 'distinct_...    True
# 8   {'ref': 'owgenialisexpressions', 'ref_type': '...    True
# 9   {'ref': None, 'ref_type': 'repository', 'maste...    True
# 10  {'push_id': 11759372407, 'size': 1, 'distinct_...    True
# 11  {'action': 'closed', 'number': 27, 'pull_reque...    True
# 12  {'ref': 'back-feature/user/fix', 'ref_type': '...    True
# 13  {'ref': 'dependabot/npm_and_yarn/karma-6.3.16'...    True
# 14                              {'action': 'started'}    True
# 15  {'action': 'closed', 'number': 4741, 'pull_req...    True
# 16  {'action': 'closed', 'number': 247, 'pull_requ...    True
# 17  {'push_id': 11759372362, 'size': 1, 'distinct_...    True
# 18  {'push_id': 11759372378, 'size': 13, 'distinct...    True
# 19  {'push_id': 11759372364, 'size': 1, 'distinct_...    True
# 20  {'action': 'created', 'issue': {'url': 'https:...    True
# 21  {'push_id': 11759372346, 'size': 1, 'distinct_...    True
# 22  {'ref': 'Stage', 'ref_type': 'branch', 'master...    True
# 23  {'action': 'opened', 'number': 138, 'pull_requ...    True
# 24  {'forkee': {'id': 569621126, 'node_id': 'R_kgD...    True
# 25  {'action': 'closed', 'number': 22, 'pull_reque...    True
# 26  {'ref': 'dependabot/npm_and_yarn/engine.io-and...    True
# 27  {'ref': 'dependabot/npm_and_yarn/mean/Angular/...    True
# 28  {'action': 'opened', 'number': 30, 'pull_reque...    True
# 29  {'push_id': 11759372318, 'size': 1, 'distinct_...    True
#
#               created_at                                                org
# 0   2022-11-23T08:44:20Z                                                NaN
# 1   2022-11-23T08:44:20Z                                                NaN
# 2   2022-11-23T08:44:20Z                                                NaN
# 3   2022-11-23T08:44:20Z                                                NaN
# 4   2022-11-23T08:44:20Z  {'id': 31246138, 'login': 'HedvigInsurance', '...
# 5   2022-11-23T08:44:20Z                                                NaN
# 6   2022-11-23T08:44:20Z  {'id': 112097473, 'login': 'RoboticsChallenge'...
# 7   2022-11-23T08:44:20Z                                                NaN
# 8   2022-11-23T08:44:20Z                                                NaN
# 9   2022-11-23T08:44:20Z                                                NaN
# 10  2022-11-23T08:44:20Z                                                NaN
# 11  2022-11-23T08:44:20Z                                                NaN
# 12  2022-11-23T08:44:20Z                                                NaN
# 13  2022-11-23T08:44:20Z                                                NaN
# 14  2022-11-23T08:44:20Z  {'id': 11708465, 'login': 'dwyl', 'gravatar_id...
# 15  2022-11-23T08:44:20Z  {'id': 70011121, 'login': 'zitadel', 'gravatar...
# 16  2022-11-23T08:44:20Z  {'id': 33544610, 'login': 'luxteam', 'gravatar...
# 17  2022-11-23T08:44:20Z  {'id': 6654105, 'login': 'waylayio', 'gravatar...
# 18  2022-11-23T08:44:20Z                                                NaN
# 19  2022-11-23T08:44:20Z                                                NaN
# 20  2022-11-23T08:44:20Z                                                NaN
# 21  2022-11-23T08:44:20Z  {'id': 15040539, 'login': 'mendersoftware', 'g...
# 22  2022-11-23T08:44:20Z                                                NaN
# 23  2022-11-23T08:44:20Z                                                NaN
# 24  2022-11-23T08:44:20Z  {'id': 7725691, 'login': 'obsproject', 'gravat...
# 25  2022-11-23T08:44:20Z                                                NaN
# 26  2022-11-23T08:44:20Z                                                NaN
# 27  2022-11-23T08:44:20Z                                                NaN
# 28  2022-11-23T08:44:20Z                                                NaN
# 29  2022-11-23T08:44:20Z                                                NaN

# %%
# to "unpack" all the columns, we can use pd.json_normalize()
pd.json_normalize(response.json())
# Out:
#              id               type  public            created_at   actor.id  \
# 0   25422925117          PushEvent    True  2022-11-23T08:44:20Z  103926885
# 1   25422925132        CreateEvent    True  2022-11-23T08:44:20Z   44438030
# 2   25422925105        MemberEvent    True  2022-11-23T08:44:20Z   34384804
# 3   25422925107        CreateEvent    True  2022-11-23T08:44:20Z  115879307
# 4   25422925091          PushEvent    True  2022-11-23T08:44:20Z   19200662
# 5   25422925078          PushEvent    True  2022-11-23T08:44:20Z   67899934
# 6   25422925076          PushEvent    True  2022-11-23T08:44:20Z  112076213
# 7   25422925046          PushEvent    True  2022-11-23T08:44:20Z   83860259
# 8   25422925035        CreateEvent    True  2022-11-23T08:44:20Z   15876321
# 9   25422925043        CreateEvent    True  2022-11-23T08:44:20Z   88604041
# 10  25422925083          PushEvent    True  2022-11-23T08:44:20Z   94271480
# 11  25422925098   PullRequestEvent    True  2022-11-23T08:44:20Z   49699333
# 12  25422925036        CreateEvent    True  2022-11-23T08:44:20Z   76932147
# 13  25422925075        DeleteEvent    True  2022-11-23T08:44:20Z   49699333
# 14  25422925038         WatchEvent    True  2022-11-23T08:44:20Z  118886360
# 15  25422925054   PullRequestEvent    True  2022-11-23T08:44:20Z   38692350
# 16  25422925045   PullRequestEvent    True  2022-11-23T08:44:20Z   49859594
# 17  25422924981          PushEvent    True  2022-11-23T08:44:20Z  106299850
# 18  25422924995          PushEvent    True  2022-11-23T08:44:20Z    1201934
# 19  25422924985          PushEvent    True  2022-11-23T08:44:20Z   96522200
# 20  25422924984  IssueCommentEvent    True  2022-11-23T08:44:20Z   49699333
# 21  25422924998          PushEvent    True  2022-11-23T08:44:20Z   28045858
# 22  25422924956        CreateEvent    True  2022-11-23T08:44:20Z  112081353
# 23  25422925023   PullRequestEvent    True  2022-11-23T08:44:20Z   49699333
# 24  25422924999          ForkEvent    True  2022-11-23T08:44:20Z   13002929
# 25  25422924994   PullRequestEvent    True  2022-11-23T08:44:20Z   49699333
# 26  25422924965        CreateEvent    True  2022-11-23T08:44:20Z   49699333
# 27  25422924975        CreateEvent    True  2022-11-23T08:44:20Z   49699333
# 28  25422924969   PullRequestEvent    True  2022-11-23T08:44:20Z   49699333
# 29  25422924901          PushEvent    True  2022-11-23T08:44:20Z  118753327
#
#             actor.login  actor.display_login actor.gravatar_id  \
# 0         surafelhabteG        surafelhabteG
# 1          Kilian-Jugie         Kilian-Jugie
# 2                 rjial                rjial
# 3                saliq7               saliq7
# 4     guilhermespopolin    guilhermespopolin
# 5               bono039              bono039
# 6            LarsAskild           LarsAskild
# 7              newegg88             newegg88
# 8           JakaKokosar          JakaKokosar
# 9             teamxhieu            teamxhieu
# 10          DaPhysikist          DaPhysikist
# 11      dependabot[bot]           dependabot
# 12        Mintfrog-1209        Mintfrog-1209
# 13      dependabot[bot]           dependabot
# 14            Dytosmany            Dytosmany
# 15           hifabienne           hifabienne
# 16          Speedwag00n          Speedwag00n
# 17  claudiu-muresan-pfa  claudiu-muresan-pfa
# 18                 a4lg                 a4lg
# 19          aishwaryakb          aishwaryakb
# 20      dependabot[bot]           dependabot
# 21                 0lmi                 0lmi
# 22             AMSAREDD             AMSAREDD
# 23      dependabot[bot]           dependabot
# 24              DIT4FUN              DIT4FUN
# 25      dependabot[bot]           dependabot
# 26      dependabot[bot]           dependabot
# 27      dependabot[bot]           dependabot
# 28      dependabot[bot]           dependabot
# 29       akshayj-chavan       akshayj-chavan
#
#                                            actor.url  \
# 0         https://api.github.com/users/surafelhabteG
# 1          https://api.github.com/users/Kilian-Jugie
# 2                 https://api.github.com/users/rjial
# 3                https://api.github.com/users/saliq7
# 4     https://api.github.com/users/guilhermespopolin
# 5               https://api.github.com/users/bono039
# 6            https://api.github.com/users/LarsAskild
# 7              https://api.github.com/users/newegg88
# 8           https://api.github.com/users/JakaKokosar
# 9             https://api.github.com/users/teamxhieu
# 10          https://api.github.com/users/DaPhysikist
# 11      https://api.github.com/users/dependabot[bot]
# 12        https://api.github.com/users/Mintfrog-1209
# 13      https://api.github.com/users/dependabot[bot]
# 14            https://api.github.com/users/Dytosmany
# 15           https://api.github.com/users/hifabienne
# 16          https://api.github.com/users/Speedwag00n
# 17  https://api.github.com/users/claudiu-muresan-pfa
# 18                 https://api.github.com/users/a4lg
# 19          https://api.github.com/users/aishwaryakb
# 20      https://api.github.com/users/dependabot[bot]
# 21                 https://api.github.com/users/0lmi
# 22             https://api.github.com/users/AMSAREDD
# 23      https://api.github.com/users/dependabot[bot]
# 24              https://api.github.com/users/DIT4FUN
# 25      https://api.github.com/users/dependabot[bot]
# 26      https://api.github.com/users/dependabot[bot]
# 27      https://api.github.com/users/dependabot[bot]
# 28      https://api.github.com/users/dependabot[bot]
# 29       https://api.github.com/users/akshayj-chavan
#
#                                      actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/103926...  ...
# 1   https://avatars.githubusercontent.com/u/44438030?  ...
# 2   https://avatars.githubusercontent.com/u/34384804?  ...
# 3   https://avatars.githubusercontent.com/u/115879...  ...
# 4   https://avatars.githubusercontent.com/u/19200662?  ...
# 5   https://avatars.githubusercontent.com/u/67899934?  ...
# 6   https://avatars.githubusercontent.com/u/112076...  ...
# 7   https://avatars.githubusercontent.com/u/83860259?  ...
# 8   https://avatars.githubusercontent.com/u/15876321?  ...
# 9   https://avatars.githubusercontent.com/u/88604041?  ...
# 10  https://avatars.githubusercontent.com/u/94271480?  ...
# 11  https://avatars.githubusercontent.com/u/49699333?  ...
# 12  https://avatars.githubusercontent.com/u/76932147?  ...
# 13  https://avatars.githubusercontent.com/u/49699333?  ...
# 14  https://avatars.githubusercontent.com/u/118886...  ...
# 15  https://avatars.githubusercontent.com/u/38692350?  ...
# 16  https://avatars.githubusercontent.com/u/49859594?  ...
# 17  https://avatars.githubusercontent.com/u/106299...  ...
# 18   https://avatars.githubusercontent.com/u/1201934?  ...
# 19  https://avatars.githubusercontent.com/u/96522200?  ...
# 20  https://avatars.githubusercontent.com/u/49699333?  ...
# 21  https://avatars.githubusercontent.com/u/28045858?  ...
# 22  https://avatars.githubusercontent.com/u/112081...  ...
# 23  https://avatars.githubusercontent.com/u/49699333?  ...
# 24  https://avatars.githubusercontent.com/u/13002929?  ...
# 25  https://avatars.githubusercontent.com/u/49699333?  ...
# 26  https://avatars.githubusercontent.com/u/49699333?  ...
# 27  https://avatars.githubusercontent.com/u/49699333?  ...
# 28  https://avatars.githubusercontent.com/u/49699333?  ...
# 29  https://avatars.githubusercontent.com/u/118753...  ...
#
#     payload.forkee.allow_forking payload.forkee.is_template  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# 5                            NaN                        NaN
# 6                            NaN                        NaN
# 7                            NaN                        NaN
# 8                            NaN                        NaN
# 9                            NaN                        NaN
# 10                           NaN                        NaN
# 11                           NaN                        NaN
# 12                           NaN                        NaN
# 13                           NaN                        NaN
# 14                           NaN                        NaN
# 15                           NaN                        NaN
# 16                           NaN                        NaN
# 17                           NaN                        NaN
# 18                           NaN                        NaN
# 19                           NaN                        NaN
# 20                           NaN                        NaN
# 21                           NaN                        NaN
# 22                           NaN                        NaN
# 23                           NaN                        NaN
# 24                          True                      False
# 25                           NaN                        NaN
# 26                           NaN                        NaN
# 27                           NaN                        NaN
# 28                           NaN                        NaN
# 29                           NaN                        NaN
#
#    payload.forkee.web_commit_signoff_required  payload.forkee.topics  \
# 0                                         NaN                    NaN
# 1                                         NaN                    NaN
# 2                                         NaN                    NaN
# 3                                         NaN                    NaN
# 4                                         NaN                    NaN
# 5                                         NaN                    NaN
# 6                                         NaN                    NaN
# 7                                         NaN                    NaN
# 8                                         NaN                    NaN
# 9                                         NaN                    NaN
# 10                                        NaN                    NaN
# 11                                        NaN                    NaN
# 12                                        NaN                    NaN
# 13                                        NaN                    NaN
# 14                                        NaN                    NaN
# 15                                        NaN                    NaN
# 16                                        NaN                    NaN
# 17                                        NaN                    NaN
# 18                                        NaN                    NaN
# 19                                        NaN                    NaN
# 20                                        NaN                    NaN
# 21                                        NaN                    NaN
# 22                                        NaN                    NaN
# 23                                        NaN                    NaN
# 24                                      False                     []
# 25                                        NaN                    NaN
# 26                                        NaN                    NaN
# 27                                        NaN                    NaN
# 28                                        NaN                    NaN
# 29                                        NaN                    NaN
#
#     payload.forkee.visibility  payload.forkee.forks  \
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                         NaN                   NaN
# 3                         NaN                   NaN
# 4                         NaN                   NaN
# 5                         NaN                   NaN
# 6                         NaN                   NaN
# 7                         NaN                   NaN
# 8                         NaN                   NaN
# 9                         NaN                   NaN
# 10                        NaN                   NaN
# 11                        NaN                   NaN
# 12                        NaN                   NaN
# 13                        NaN                   NaN
# 14                        NaN                   NaN
# 15                        NaN                   NaN
# 16                        NaN                   NaN
# 17                        NaN                   NaN
# 18                        NaN                   NaN
# 19                        NaN                   NaN
# 20                        NaN                   NaN
# 21                        NaN                   NaN
# 22                        NaN                   NaN
# 23                        NaN                   NaN
# 24                     public                   0.0
# 25                        NaN                   NaN
# 26                        NaN                   NaN
# 27                        NaN                   NaN
# 28                        NaN                   NaN
# 29                        NaN                   NaN
#
#    payload.forkee.open_issues payload.forkee.watchers  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                         NaN                     NaN
# 4                         NaN                     NaN
# 5                         NaN                     NaN
# 6                         NaN                     NaN
# 7                         NaN                     NaN
# 8                         NaN                     NaN
# 9                         NaN                     NaN
# 10                        NaN                     NaN
# 11                        NaN                     NaN
# 12                        NaN                     NaN
# 13                        NaN                     NaN
# 14                        NaN                     NaN
# 15                        NaN                     NaN
# 16                        NaN                     NaN
# 17                        NaN                     NaN
# 18                        NaN                     NaN
# 19                        NaN                     NaN
# 20                        NaN                     NaN
# 21                        NaN                     NaN
# 22                        NaN                     NaN
# 23                        NaN                     NaN
# 24                        0.0                     0.0
# 25                        NaN                     NaN
# 26                        NaN                     NaN
# 27                        NaN                     NaN
# 28                        NaN                     NaN
# 29                        NaN                     NaN
#
#    payload.forkee.default_branch payload.forkee.public
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# 5                            NaN                   NaN
# 6                            NaN                   NaN
# 7                            NaN                   NaN
# 8                            NaN                   NaN
# 9                            NaN                   NaN
# 10                           NaN                   NaN
# 11                           NaN                   NaN
# 12                           NaN                   NaN
# 13                           NaN                   NaN
# 14                           NaN                   NaN
# 15                           NaN                   NaN
# 16                           NaN                   NaN
# 17                           NaN                   NaN
# 18                           NaN                   NaN
# 19                           NaN                   NaN
# 20                           NaN                   NaN
# 21                           NaN                   NaN
# 22                           NaN                   NaN
# 23                           NaN                   NaN
# 24                          main                  True
# 25                           NaN                   NaN
# 26                           NaN                   NaN
# 27                           NaN                   NaN
# 28                           NaN                   NaN
# 29                           NaN                   NaN
#
# [30 rows x 580 columns]

# %% [markdown]
# ### Intenational Space Station
#
# Docs here: http://open-notify.org/Open-Notify-API/ISS-Location-Now/

# %%
# Make a get request to get the latest position of the international space station from the opennotify api.
response = requests.get("http://api.open-notify.org/iss-now.json")
# Print the status code of the response.
response.status_code
# Out:
# 200

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-now.json'

# %%
response.json()
# Out:
# {'message': 'success',
#  'iss_position': {'latitude': '-8.5612', 'longitude': '66.2632'},
#  'timestamp': 1669193423}

# %% [markdown]
# {'iss_position': {'latitude': '10.7064', 'longitude': '-27.9890'},
#  'message': 'success',
#  'timestamp': 1623745101}

# %%
# last time it was over ironhack
  ## 52.53370520371973, 13.453475292072312
coordinates = {"lat": 52.53370520371973, "lon": 13.453475292072312}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=coordinates)

# %%
response.status_code
# Out:
# 404

# %%
response.url
# Out:
# 'http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312'

# %%
response = requests.get('http://api.open-notify.org/iss-pass.json?lat=52.53370520371973&lon=13.453475292072312')

# %%
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1650978537,
#   'latitude': 52.53370520371973,
#   'longitude': 13.453475292072312,
#   'passes': 5},
#  'response': [{'duration': 210, 'risetime': 1651022628},
#   {'duration': 580, 'risetime': 1651028180},
#   {'duration': 645, 'risetime': 1651033924},
#   {'duration': 652, 'risetime': 1651039720},
#   {'duration': 639, 'risetime': 1651045522}]}

# %%
from datetime import datetime
datetime.fromtimestamp(1645005884)
# Out:
# datetime.datetime(2022, 2, 16, 11, 4, 44)

# %%
pd.to_datetime(1637772367, unit="s")
# Out:
# Timestamp('2021-11-24 16:46:07')
